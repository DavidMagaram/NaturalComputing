# %%
# !cat english.test tagalog.test > english_tagalog.test
for i in range(1,10):
    # !java -jar negsel2.jar -self english.train -n 10 -r {i} -c -l < english_tagalog.test > baseline{i}.txt
# Out:
# ^C
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

with open("english.test", 'r') as fp:
    lines_n_en = len(fp.readlines())
with open("tagalog.test", 'r') as fp:
    lines_n_tag = len(fp.readlines())
with open("baseline4.txt", 'r') as fp:
    results=[]
    for i, line in enumerate(fp):
        results.append((float(line[0:-2]), i<lines_n_en))
    print(results)
# Out:
# [(31.28688502358204, True), (30.466003420722288, True), (31.28297578474523, True), (31.193802630398302, True), (29.920970286174253, True), (30.75399337079625, True), (0.0, True), (30.948096414958346, True), (31.259194770452407, True), (31.054991150245414, True), (31.2663259506871, True), (31.220744696768932, True), (30.42536618554444, True), (31.28367893428539, True), (31.057289970024925, True), (31.28400001465524, True), (30.735357048556036, True), (31.03537930449808, True), (30.009981169757218, True), (31.04862145526373, True), (31.03343052871269, True), (31.27456984180262, True), (31.261143214870614, True), (31.212666261872354, True), (31.25017988564411, True), (31.024384804042157, True), (31.264540491667447, True), (31.282804346103486, True), (30.755720854173017, True), (30.769845900984283, True), (30.052079882106593, True), (30.77707122184107, True), (30.763259978109566, True), (30.981647716507915, True), (31.24823850884811, True), (30.777609000654824, True), (31.021897879236597
# ...
