# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def load_scores(file_path):
    return np.loadtxt(file_path)

for r in range(1, 10):
    english = load_scores(f"./results/english_r{r}.txt")
    tagalog = load_scores(f"./results/tagalog_r{r}.txt")
    
    scores = np.concatenate([english, tagalog])
    labels = np.concatenate([np.zeros(len(english)), np.ones(len(tagalog))])
    
    fpr, tpr, thresholds = roc_curve(labels, scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"r = {r}, AUC = {roc_auc:.4f}")
    
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--', color='gray')
    plt.xlabel("1 - Specificity (FPR)")
    plt.ylabel("Sensitivity (TPR)")
    plt.title(f"ROC Curve (r = {r})")
    plt.legend()
    plt.show()   # <- this displays the plot and waits until you close it
# Out:
# r = 1, AUC = 0.5435
# r = 2, AUC = 0.7396
# r = 3, AUC = 0.8311
# r = 4, AUC = 0.7916
# r = 5, AUC = 0.7282
# r = 6, AUC = 0.6681
# r = 7, AUC = 0.5907
# r = 8, AUC = 0.5202
# r = 9, AUC = 0.5121

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def load_scores(file_path):
    return np.loadtxt(file_path)

for r in range(1, 10):
    english = load_scores(f"./results/english_r{r}.txt")
    tagalog = load_scores(f"./results/xhosa_r{r}.txt")
    
    scores = np.concatenate([english, tagalog])
    labels = np.concatenate([np.zeros(len(english)), np.ones(len(tagalog))])
    
    fpr, tpr, thresholds = roc_curve(labels, scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"r = {r}, AUC = {roc_auc:.4f}")
    
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--', color='gray')
    plt.xlabel("1 - Specificity (FPR)")
    plt.ylabel("Sensitivity (TPR)")
    plt.title(f"ROC Curve (r = {r})")
    plt.legend()
    plt.show()   # <- this displays the plot and waits until you close it
# Out:
# r = 1, AUC = 0.6192
# r = 2, AUC = 0.8517
# r = 3, AUC = 0.8893
# r = 4, AUC = 0.8323
# r = 5, AUC = 0.7646
# r = 6, AUC = 0.6916
# r = 7, AUC = 0.5888
# r = 8, AUC = 0.5202
# r = 9, AUC = 0.5121

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def load_scores(file_path):
    return np.loadtxt(file_path)

for r in range(1, 10):
    english = load_scores(f"./results/english_r{r}.txt")
    tagalog = load_scores(f"./results/middle-english_r{r}.txt")
    
    scores = np.concatenate([english, tagalog])
    labels = np.concatenate([np.zeros(len(english)), np.ones(len(tagalog))])
    
    fpr, tpr, thresholds = roc_curve(labels, scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"r = {r}, AUC = {roc_auc:.4f}")
    
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--', color='gray')
    plt.xlabel("1 - Specificity (FPR)")
    plt.ylabel("Sensitivity (TPR)")
    plt.title(f"ROC Curve (r = {r})")
    plt.legend()
    plt.show()   # <- this displays the plot and waits until you close it
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 9
#       6     return np.loadtxt(file_path)
#       8 for r in range(1, 10):
# ----> 9     english = load_scores(f"/results/english_r{r}.txt")
#      10     tagalog = load_scores(f"/results/middle-english_r{r}.txt")
#      12     scores = np.concatenate([english, tagalog])
#
# Cell In[7], line 6, in load_scores(file_path)
#       5 def load_scores(file_path):
# ----> 6     return np.loadtxt(file_path)
#
# File ~/miniforge3/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File ~/miniforge3/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1024, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1022     fname = os.fspath(fname)
#    1023 if isinstance(fname, str):
# -> 1024     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1025     if encoding is None:
#    1026         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniforge3/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniforge3/lib/python3.12/site-packages/numpy/lib/_datasource.py:526, in DataSource.open(self, path, mode, encoding, newline)
#     524     if ext == 'bz2':
#     525         mode.replace("+", "")
# --> 526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
#     529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/results/english_r1.txt'

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def load_scores(file_path):
    return np.loadtxt(file_path)

for r in range(1, 10):
    english = load_scores(f"./results/english_r{r}.txt")
    tagalog = load_scores(f"./results/plautdietsch_r{r}.txt")
    
    scores = np.concatenate([english, tagalog])
    labels = np.concatenate([np.zeros(len(english)), np.ones(len(tagalog))])
    
    fpr, tpr, thresholds = roc_curve(labels, scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"r = {r}, AUC = {roc_auc:.4f}")
    
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--', color='gray')
    plt.xlabel("1 - Specificity (FPR)")
    plt.ylabel("Sensitivity (TPR)")
    plt.title(f"ROC Curve (r = {r})")
    plt.legend()
    plt.show()   # <- this displays the plot and waits until you close it
# Out:
# r = 1, AUC = 0.6553
# r = 2, AUC = 0.7070
# r = 3, AUC = 0.7747
# r = 4, AUC = 0.7534
# r = 5, AUC = 0.7014
# r = 6, AUC = 0.6501
# r = 7, AUC = 0.5856
# r = 8, AUC = 0.5192
# r = 9, AUC = 0.5121

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def load_scores(file_path):
    return np.loadtxt(file_path)

for r in range(1, 10):
    english = load_scores(f"./results/english_r{r}.txt")
    tagalog = load_scores(f"./results/hiligaynon_r{r}.txt")
    
    scores = np.concatenate([english, tagalog])
    labels = np.concatenate([np.zeros(len(english)), np.ones(len(tagalog))])
    
    fpr, tpr, thresholds = roc_curve(labels, scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"r = {r}, AUC = {roc_auc:.4f}")
    
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--', color='gray')
    plt.xlabel("1 - Specificity (FPR)")
    plt.ylabel("Sensitivity (TPR)")
    plt.title(f"ROC Curve (r = {r})")
    plt.legend()
    plt.show()   # <- this displays the plot and waits until you close it
# Out:
# r = 1, AUC = 0.5460
# r = 2, AUC = 0.7519
# r = 3, AUC = 0.8397
# r = 4, AUC = 0.7975
# r = 5, AUC = 0.7302
# r = 6, AUC = 0.6709
# r = 7, AUC = 0.5933
# r = 8, AUC = 0.5202
# r = 9, AUC = 0.5121
